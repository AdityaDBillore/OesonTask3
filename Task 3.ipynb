# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing and reading the datasets

# %%
covid_state = pd.read_csv('StatewiseTestingDetails.csv')
covid_india = pd.read_csv('covid_19_india.csv')
zones = pd.read_csv('Zones.csv')
us = pd.read_csv('us_covid19_daily.csv')
us_states = pd.read_csv('us_states_covid19_daily.csv')
italy_region = pd.read_csv('covid19_italy_region.csv')
italy_province = pd.read_csv('covid19_italy_province.csv')
age_group = pd.read_csv('AgeGroupDetails.csv')
complete = pd.read_csv('complete.csv')
hosp = pd.read_csv('HospitalBedsIndia.csv')
icmr = pd.read_csv('ICMR_Testing_Data.csv')
icmr2 = pd.read_csv('ICMRTestingLabs.csv')
individual = pd.read_csv('IndividualDetails.csv')
popu = pd.read_csv('population_india_census2011.csv')

# %%
covid_state
# Out:
#             Date                        State  TotalSamples  Negative  \
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0    1210.0
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0       NaN
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0       NaN
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0       NaN
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0       NaN
# ...          ...                          ...           ...       ...
# 1989  2020-06-08                  West Bengal      280098.0       NaN
# 1990  2020-06-09                  West Bengal      287900.0       NaN
# 1991  2020-06-10                  West Bengal      297419.0       NaN
# 1992  2020-06-11                  West Bengal      306941.0       NaN
# 1993  2020-06-12                  West Bengal      315699.0       NaN
#
#       Positive
# 0         12.0
# 1         27.0
# 2         33.0
# 3         33.0
# 4         33.0
# ...        ...
# ...

# %%
covid_india
# Out:
#        Sno      Date     Time              State/UnionTerritory  \
# 0        1  30/01/20  6:00 PM                            Kerala
# 1        2  31/01/20  6:00 PM                            Kerala
# 2        3  01/02/20  6:00 PM                            Kerala
# 3        4  02/02/20  6:00 PM                            Kerala
# 4        5  03/02/20  6:00 PM                            Kerala
# ...    ...       ...      ...                               ...
# 2986  2987  13/06/20  8:00 AM                           Tripura
# 2987  2988  13/06/20  8:00 AM                       Uttarakhand
# 2988  2989  13/06/20  8:00 AM                     Uttar Pradesh
# 2989  2990  13/06/20  8:00 AM                       West Bengal
# 2990  2991  13/06/20  8:00 AM  Cases being reassigned to states
#
#      ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 0                          1                        0      0       0
# ...

# %%
zones
# Out:
#                      district    zone                 districtcode  \
# 0                    Nicobars   Green                  AN_Nicobars
# 1    North and Middle Andaman   Green  AN_North and Middle Andaman
# 2               South Andaman     Red             AN_South Andaman
# 3                   Anantapur  Orange                 AP_Anantapur
# 4                    Chittoor     Red                  AP_Chittoor
# ..                        ...     ...                          ...
# 730           Purba Bardhaman  Orange           WB_Purba Bardhaman
# 731           Purba Medinipur     Red           WB_Purba Medinipur
# 732                   Purulia   Green                   WB_Purulia
# 733       South Red4 Parganas  Orange       WB_South Red4 Parganas
# 734            Uttar Dinajpur   Green            WB_Uttar Dinajpur
#
#                            state statecode
# 0    Andaman and Nicobar Islands        AN
# 1    Andaman and Nicobar Islands        AN
# ...

# %%
us
# Out:
#          date  states  positive    negative  pending  hospitalizedCurrently  \
# 0    20200612      56   2037530  20479732.0   1783.0                28524.0
# 1    20200611      56   2013778  19919523.0   1816.0                29064.0
# 2    20200610      56   1991527  19495009.0   1737.0                30203.0
# 3    20200609      56   1970765  19096303.0   1661.0                30547.0
# 4    20200608      56   1953730  18699572.0   1606.0                29969.0
# ..        ...     ...       ...         ...      ...                    ...
# 138  20200126       1         1         NaN      NaN                    NaN
# 139  20200125       1         1         NaN      NaN                    NaN
# 140  20200124       1         1         NaN      NaN                    NaN
# 141  20200123       1         1         NaN      NaN                    NaN
# 142  20200122       1         1         NaN      NaN                    NaN
#
# ...

# %%
us_states
# Out:
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200612    AK     625.0   70255.0      NaN                   15.0
# 1     20200612    AL   23710.0  262675.0      NaN                  622.0
# 2     20200612    AR   11547.0  169575.0      NaN                  203.0
# 3     20200612    AS       0.0     174.0      NaN                    NaN
# 4     20200612    AZ   32918.0  278318.0      NaN                 1336.0
# ...        ...   ...       ...       ...      ...                    ...
# 5556  20200126    WA       1.0       NaN      NaN                    NaN
# 5557  20200125    WA       1.0       NaN      NaN                    NaN
# 5558  20200124    WA       1.0       NaN      NaN                    NaN
# 5559  20200123    WA       1.0       NaN      NaN                    NaN
# 5560  20200122    WA       1.0       NaN      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
italy_region
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 0        0  2020-02-24T18:00:00     ITA          13        Abruzzo  42.351222
# 1        1  2020-02-24T18:00:00     ITA          17     Basilicata  40.639471
# 2        2  2020-02-24T18:00:00     ITA          21   P.A. Bolzano  46.499335
# 3        3  2020-02-24T18:00:00     ITA          18       Calabria  38.905976
# 4        4  2020-02-24T18:00:00     ITA          15       Campania  40.839566
# ...    ...                  ...     ...         ...            ...        ...
# 2305  2305  2020-06-12T17:00:00     ITA           9        Toscana  43.769231
# 2306  2306  2020-06-12T17:00:00     ITA          22    P.A. Trento  46.068935
# 2307  2307  2020-06-12T17:00:00     ITA          10         Umbria  43.106758
# 2308  2308  2020-06-12T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 2309  2309  2020-06-12T17:00:00     ITA           5         Veneto  45.434905
#
# ...

# %%
italy_province
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 0          0  2020-02-24T18:00:00     ITA          13    Abruzzo
# 1          1  2020-02-24T18:00:00     ITA          13    Abruzzo
# 2          2  2020-02-24T18:00:00     ITA          13    Abruzzo
# 3          3  2020-02-24T18:00:00     ITA          13    Abruzzo
# 4          4  2020-02-24T18:00:00     ITA          13    Abruzzo
# ...      ...                  ...     ...         ...        ...
# 14075  14075  2020-06-12T17:00:00     ITA           5     Veneto
# 14076  14076  2020-06-12T17:00:00     ITA           5     Veneto
# 14077  14077  2020-06-12T17:00:00     ITA           5     Veneto
# 14078  14078  2020-06-12T17:00:00     ITA           5     Veneto
# 14079  14079  2020-06-12T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 0                69                                Chieti
# 1                66                              L'Aquila
# ...

# %% [markdown]
# # Reading shapes and detail exploration of all the datasets

# %%
print('The shape of the Covid India dataset is {}'.format(covid_india.shape))
print('The shape of the Statewise Testing Details dataset is {}'.format(covid_state.shape))
print('The shape od the Zones dataset is {}'.format(zones.shape))
print('The shape of US_daily dataset is {}'.format(us.shape))
print('The shape of US_states_daily is {}'.format(us_states.shape))
print('The shape of Italy region dataset is {}'.format(italy_region.shape))
print('The shape Italy province dataset is {}'.format(italy_province.shape))
# Out:
# The shape of the Covid India dataset is (2991, 9)
# The shape of the Statewise Testing Details dataset is (1994, 5)
# The shape od the Zones dataset is (735, 5)
# The shape of US_daily dataset is (143, 25)
# The shape of US_states_daily is (5561, 39)
# The shape of Italy region dataset is (2310, 17)
# The shape Italy province dataset is (14080, 11)

# %%
covid_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       2991 non-null   int64
#  1   Date                      2991 non-null   object
#  2   Time                      2991 non-null   object
#  3   State/UnionTerritory      2991 non-null   object
#  4   ConfirmedIndianNational   2991 non-null   object
#  5   ConfirmedForeignNational  2991 non-null   object
#  6   Cured                     2991 non-null   int64
#  7   Deaths                    2991 non-null   int64
#  8   Confirmed                 2991 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 210.4+ KB

# %%
covid_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1994 non-null   object
#  1   State         1994 non-null   object
#  2   TotalSamples  1994 non-null   float64
#  3   Negative      1527 non-null   float64
#  4   Positive      1986 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 78.0+ KB

# %%
zones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      735 non-null    object
#  1   zone          733 non-null    object
#  2   districtcode  735 non-null    object
#  3   state         735 non-null    object
#  4   statecode     735 non-null    object
# dtypes: object(5)
# memory usage: 28.8+ KB

# %%
us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      143 non-null    int64
#  1   states                    143 non-null    int64
#  2   positive                  143 non-null    int64
#  3   negative                  105 non-null    float64
#  4   pending                   101 non-null    float64
#  5   hospitalizedCurrently     88 non-null     float64
#  6   hospitalizedCumulative    84 non-null     float64
#  7   inIcuCurrently            79 non-null     float64
#  8   inIcuCumulative           80 non-null     float64
#  9   onVentilatorCurrently     80 non-null     float64
#  10  onVentilatorCumulative    73 non-null     float64
#  11  recovered                 80 non-null     float64
#  12  dateChecked               143 non-null    object
# ...

# %%
us_states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5561 entries, 0 to 5560
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      5561 non-null   int64
#  1   state                     5561 non-null   object
#  2   positive                  5546 non-null   float64
#  3   negative                  5343 non-null   float64
#  4   pending                   874 non-null    float64
#  5   hospitalizedCurrently     2963 non-null   float64
#  6   hospitalizedCumulative    2607 non-null   float64
#  7   inIcuCurrently            1554 non-null   float64
#  8   inIcuCumulative           664 non-null    float64
#  9   onVentilatorCurrently     1349 non-null   float64
#  10  onVentilatorCumulative    230 non-null    float64
#  11  recovered                 2777 non-null   float64
#  12  dataQualityGrade          4460 non-null   object
# ...

# %%
italy_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SNo                        2310 non-null   int64
#  1   Date                       2310 non-null   object
#  2   Country                    2310 non-null   object
#  3   RegionCode                 2310 non-null   int64
#  4   RegionName                 2310 non-null   object
#  5   Latitude                   2310 non-null   float64
#  6   Longitude                  2310 non-null   float64
#  7   HospitalizedPatients       2310 non-null   int64
#  8   IntensiveCarePatients      2310 non-null   int64
#  9   TotalHospitalizedPatients  2310 non-null   int64
#  10  HomeConfinement            2310 non-null   int64
#  11  CurrentPositiveCases       2310 non-null   int64
#  12  NewPositiveCases           2310 non-null   int64
# ...

# %%
italy_province.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14080 entries, 0 to 14079
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SNo                   14080 non-null  int64
#  1   Date                  14080 non-null  object
#  2   Country               14080 non-null  object
#  3   RegionCode            14080 non-null  int64
#  4   RegionName            14080 non-null  object
#  5   ProvinceCode          14080 non-null  int64
#  6   ProvinceName          14080 non-null  object
#  7   ProvinceAbbreviation  11660 non-null  object
#  8   Latitude              14080 non-null  float64
#  9   Longitude             14080 non-null  float64
#  10  TotalPositiveCases    14080 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 1.2+ MB

# %%
covid_india.describe()
# Out:
#                Sno         Cured       Deaths      Confirmed
# count  2991.000000   2991.000000  2991.000000    2991.000000
# mean   1496.000000    927.865597    64.840187    2202.333668
# std     863.571653   3354.157599   264.954939    7548.386880
# min       1.000000      0.000000     0.000000       0.000000
# 25%     748.500000      1.000000     0.000000      12.000000
# 50%    1496.000000     25.000000     1.000000      94.000000
# 75%    2243.500000    360.000000    17.000000    1259.000000
# max    2991.000000  47796.000000  3717.000000  101141.000000

# %%
covid_state.describe()
# Out:
#         TotalSamples       Negative      Positive
# count    1994.000000    1527.000000   1986.000000
# mean    73794.491474   73182.284217   3096.557402
# std    114354.970503  115780.797230   8816.283350
# min        58.000000       0.000000      0.000000
# 25%      4928.000000    4734.000000     38.000000
# 50%     21328.500000   20300.000000    380.500000
# 75%     95019.500000   87020.500000   2194.000000
# max    673906.000000  632656.000000  97648.000000

# %%
us.describe()
# Out:
#                date      states      positive      negative       pending  \
# count  1.430000e+02  143.000000  1.430000e+02  1.050000e+02    101.000000
# mean   2.020037e+07   38.888112  6.235601e+05  5.865555e+06  10709.059406
# std    1.400072e+02   24.882005  7.069209e+05  6.152181e+06  17621.501815
# min    2.020012e+07    1.000000  1.000000e+00  1.400000e+01    103.000000
# 25%    2.020023e+07    1.000000  2.000000e+00  4.733780e+05   1816.000000
# 50%    2.020040e+07   56.000000  2.525570e+05  3.395206e+06   3368.000000
# 75%    2.020051e+07   56.000000  1.269668e+06  1.000489e+07  11324.000000
# max    2.020061e+07   56.000000  2.037530e+06  2.047973e+07  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              88.000000               84.000000       79.000000
# mean            37154.784091           123210.238095     9422.291139
# std             17241.033805            70238.908508     3599.770474
# ...

# %%
us_states.describe()
# Out:
#                date       positive      negative       pending  \
# count  5.561000e+03    5546.000000  5.343000e+03    874.000000
# mean   2.020044e+07   16078.090335  1.152692e+05   1237.545767
# std    9.818095e+01   40835.578634  2.354172e+05   6502.877347
# min    2.020012e+07       0.000000  0.000000e+00      0.000000
# 25%    2.020033e+07     254.000000  5.018000e+03     12.000000
# 50%    2.020042e+07    2762.000000  3.508100e+04     72.500000
# 75%    2.020052e+07   13801.250000  1.229455e+05    477.000000
# max    2.020061e+07  381714.000000  2.520275e+06  64400.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count            2963.000000             2607.000000     1554.000000
# mean             1103.483294             3969.950134      478.996782
# std              2080.759373            12580.520197      744.812804
# min                 1.000000                0.000000        2.000000
# ...

# %%
italy_region.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  2310.000000  2310.000000  2310.000000  2310.000000
# mean   1154.500000    11.857143    43.046293    12.225955
# std     666.983883     6.275157     2.489320     2.659523
# min       0.000000     1.000000    38.115697     7.320149
# 25%     577.250000     7.000000    41.125596    11.121231
# 50%    1154.500000    12.000000    43.616760    12.388247
# 75%    1731.750000    17.000000    45.434905    13.768136
# max    2309.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           2310.000000            2310.000000                2310.000000
# mean             684.235498              78.864069                 763.099567
# std             1633.762466             172.350104                1799.733222
# min                0.000000               0.000000                   0.000000
# ...

# %%
italy_province.describe()
# Out:
#                SNo    RegionCode  ProvinceCode      Latitude     Longitude  \
# count  14080.00000  14080.000000  14080.000000  14080.000000  14080.000000
# mean    7039.50000     10.687500    207.523438     35.868843     10.112000
# std     4064.69023      6.127449    347.395365     16.072095      5.097773
# min        0.00000      1.000000      1.000000      0.000000      0.000000
# 25%     3519.75000      5.750000     32.750000     38.848542      8.583304
# 50%     7039.50000     10.000000     64.500000     42.609815     11.188560
# 75%    10559.25000     16.000000     96.250000     44.947714     13.593962
# max    14079.00000     22.000000    999.000000     46.499335     18.171897
#
#        TotalPositiveCases
# count        14080.000000
# mean          1127.447372
# std           2354.489943
# min              0.000000
# 25%             30.000000
# 50%            325.000000
# 75%           1107.250000
# max          23669.000000

# %%
covid_india.isna().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
zones.isna().sum()
# Out:
# district        0
# zone            2
# districtcode    0
# state           0
# statecode       0
# dtype: int64

# %%
zones = zones.dropna()

# %%
zones.isna().sum()
# Out:
# district        0
# zone            0
# districtcode    0
# state           0
# statecode       0
# dtype: int64

# %%
us.isna().sum()
# Out:
# date                         0
# states                       0
# positive                     0
# negative                    38
# pending                     42
# hospitalizedCurrently       55
# hospitalizedCumulative      59
# inIcuCurrently              64
# inIcuCumulative             63
# onVentilatorCurrently       63
# onVentilatorCumulative      70
# recovered                   63
# dateChecked                  0
# death                       35
# hospitalized                59
# lastModified                 0
# total                        0
# totalTestResults             0
# posNeg                       0
# deathIncrease                0
# hospitalizedIncrease         0
# negativeIncrease             0
# positiveIncrease             0
# totalTestResultsIncrease     0
# hash                         0
# dtype: int64

# %%
us_states.isna().sum()
# Out:
# date                           0
# state                          0
# positive                      15
# negative                     218
# pending                     4687
# hospitalizedCurrently       2598
# hospitalizedCumulative      2954
# inIcuCurrently              4007
# inIcuCumulative             4897
# onVentilatorCurrently       4212
# onVentilatorCumulative      5331
# recovered                   2784
# dataQualityGrade            1101
# lastUpdateEt                 355
# dateModified                 355
# checkTimeEt                  355
# death                        720
# hospitalized                2954
# dateChecked                  355
# totalTestsViral             4436
# positiveTestsViral          5067
# negativeTestsViral          5068
# positiveCasesViral          3105
# fips                           0
# positiveIncrease               0
# negativeIncrease               0
# total                          0
# totalTestResults               0
# ...

# %%
us = us.dropna()

# %%
italy_region.isna().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
italy_province.isna().sum()
# Out:
# SNo                        0
# Date                       0
# Country                    0
# RegionCode                 0
# RegionName                 0
# ProvinceCode               0
# ProvinceName               0
# ProvinceAbbreviation    2420
# Latitude                   0
# Longitude                  0
# TotalPositiveCases         0
# dtype: int64

# %%
covid_state.isna().sum()
# Out:
# Date              0
# State             0
# TotalSamples      0
# Negative        467
# Positive          8
# dtype: int64

# %% [markdown]
# Here in StatewiseTestingDetails.csv, there are many null values. There are two ways of dealing with null values, viz., either you can drop the null values or you can fill the missing values with mean, median, or mode. But in our dataset, Negative column can be filledd by subtracting positive cases from total samples. The process is shown below

# %%
covid_state['Positive'].fillna(0, inplace = True)

# %%
"Filling negative cases , We counted the values by using values in TotalSamples and positive column"

covid_state['Negative'] = covid_state['TotalSamples'] - covid_state['Positive']
covid_state
# Out:
#             Date                        State  TotalSamples  Negative  \
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0    1391.0
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0    2652.0
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0    2815.0
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0    3721.0
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0    6644.0
# ...          ...                          ...           ...       ...
# 1989  2020-06-08                  West Bengal      280098.0  271485.0
# 1990  2020-06-09                  West Bengal      287900.0  278915.0
# 1991  2020-06-10                  West Bengal      297419.0  288091.0
# 1992  2020-06-11                  West Bengal      306941.0  297173.0
# 1993  2020-06-12                  West Bengal      315699.0  305455.0
#
#       Positive
# 0         12.0
# 1         27.0
# 2         33.0
# 3         33.0
# 4         33.0
# ...        ...
# ...

# %%
covid_state.isna().sum()
# Out:
# Date            0
# State           0
# TotalSamples    0
# Negative        0
# Positive        0
# dtype: int64

# %%
us_states['state'].value_counts()
# Out:
# WA    143
# RI    104
# MI    104
# TX    101
# NC    101
# NH    101
# SC    101
# GA    101
# FL    101
# IL    101
# OR    101
# WI    101
# CA    101
# AZ    101
# NY    101
# TN    100
# MD    100
# OH    100
# NE    100
# VA    100
# DC    100
# CO    100
# NV    100
# NJ    100
# PA     99
# NM     99
# AK     99
# MN     99
# KS     99
# IN     99
# IA     99
# VT     99
# DE     99
# WV     99
# AR     99
# KY     99
# SD     98
# UT     98
# OK     98
# MS     98
# ND     98
# MT     98
# AL     98
# MO     98
# ME     98
# LA     98
# ID     98
# HI     98
# CT     98
# WY     98
# MA     93
# PR     89
# MP     89
# VI     89
# GU     89
# AS     89
# Name: state, dtype: int64

# %%
us_states['date']= us_states['date'].astype('str')
us_states['date'] = pd.to_datetime(us_states['date'])
print (us_states['date'])
us_states.head()
# Out:
# 0      2020-06-12
# 1      2020-06-12
# 2      2020-06-12
# 3      2020-06-12
# 4      2020-06-12
#           ...
# 5556   2020-01-26
# 5557   2020-01-25
# 5558   2020-01-24
# 5559   2020-01-23
# 5560   2020-01-22
# Name: date, Length: 5561, dtype: datetime64[ns]
#         date state  positive  negative  pending  hospitalizedCurrently  \
# 0 2020-06-12    AK     625.0   70255.0      NaN                   15.0
# 1 2020-06-12    AL   23710.0  262675.0      NaN                  622.0
# 2 2020-06-12    AR   11547.0  169575.0      NaN                  203.0
# 3 2020-06-12    AS       0.0     174.0      NaN                    NaN
# 4 2020-06-12    AZ   32918.0  278318.0      NaN                 1336.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                  2202.0             NaN            658.0
# 2                   961.0             NaN              NaN
# ...

# %%
"finding unique values from 'State/UnionTerritory' column"

covid_india['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya', 'Dadar Nagar Haveli',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Telangana'],
#       dtype=object)

# %%
covid_india['Date']
# Out:
# 0       30/01/20
# 1       31/01/20
# 2       01/02/20
# 3       02/02/20
# 4       03/02/20
#           ...
# 2986    13/06/20
# 2987    13/06/20
# 2988    13/06/20
# 2989    13/06/20
# 2990    13/06/20
# Name: Date, Length: 2991, dtype: object

# %%
"Changing the format of date"

covid_india['Date'] = pd.to_datetime(covid_india['Date'])
covid_india['Date'] = covid_india['Date'].dt.strftime('%d-%m-%Y')
covid_india['Date']
# Out:
# 0       30-01-2020
# 1       31-01-2020
# 2       02-01-2020
# 3       02-02-2020
# 4       02-03-2020
#            ...
# 2986    13-06-2020
# 2987    13-06-2020
# 2988    13-06-2020
# 2989    13-06-2020
# 2990    13-06-2020
# Name: Date, Length: 2991, dtype: object

# %%
"Removing unwanted columns from dataset using 'drop'."

covid_india.drop(['Time','ConfirmedIndianNational','ConfirmedForeignNational'],axis = 1,inplace = True)
covid_india
# Out:
#        Sno        Date              State/UnionTerritory  Cured  Deaths  \
# 0        1  30-01-2020                            Kerala      0       0
# 1        2  31-01-2020                            Kerala      0       0
# 2        3  02-01-2020                            Kerala      0       0
# 3        4  02-02-2020                            Kerala      0       0
# 4        5  02-03-2020                            Kerala      0       0
# ...    ...         ...                               ...    ...     ...
# 2986  2987  13-06-2020                           Tripura    278       1
# 2987  2988  13-06-2020                       Uttarakhand    947      21
# 2988  2989  13-06-2020                     Uttar Pradesh   7609     365
# 2989  2990  13-06-2020                       West Bengal   4206     451
# 2990  2991  13-06-2020  Cases being reassigned to states      0       0
#
#       Confirmed
# 0             1
# 1             1
# 2             2
# 3             3
# ...

# %%
"Identifying active cases , We counted the values by using values in confirmed, cured, deaths column"

covid_india['Active'] = covid_india['Confirmed'] - covid_india['Cured'] - covid_india['Deaths']
covid_india
# Out:
#        Sno        Date              State/UnionTerritory  Cured  Deaths  \
# 0        1  30-01-2020                            Kerala      0       0
# 1        2  31-01-2020                            Kerala      0       0
# 2        3  02-01-2020                            Kerala      0       0
# 3        4  02-02-2020                            Kerala      0       0
# 4        5  02-03-2020                            Kerala      0       0
# ...    ...         ...                               ...    ...     ...
# 2986  2987  13-06-2020                           Tripura    278       1
# 2987  2988  13-06-2020                       Uttarakhand    947      21
# 2988  2989  13-06-2020                     Uttar Pradesh   7609     365
# 2989  2990  13-06-2020                       West Bengal   4206     451
# 2990  2991  13-06-2020  Cases being reassigned to states      0       0
#
#       Confirmed  Active
# 0             1       1
# 1             1       1
# 2             2       2
# ...

# %%
covid_state
# Out:
#             Date                        State  TotalSamples  Negative  \
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0    1391.0
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0    2652.0
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0    2815.0
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0    3721.0
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0    6644.0
# ...          ...                          ...           ...       ...
# 1989  2020-06-08                  West Bengal      280098.0  271485.0
# 1990  2020-06-09                  West Bengal      287900.0  278915.0
# 1991  2020-06-10                  West Bengal      297419.0  288091.0
# 1992  2020-06-11                  West Bengal      306941.0  297173.0
# 1993  2020-06-12                  West Bengal      315699.0  305455.0
#
#       Positive
# 0         12.0
# 1         27.0
# 2         33.0
# 3         33.0
# 4         33.0
# ...        ...
# ...

# %%
"Top 10 states where more sample testing is done"

state_top_10 = covid_state.nlargest(10,['TotalSamples'])

state_top_10 = covid_state.groupby(['State'])['TotalSamples'].max().sort_values(ascending=False).reset_index()
state_top = state_top_10.nlargest(10,['TotalSamples'])
state_top
# Out:
#                State  TotalSamples
# 0         Tamil Nadu      673906.0
# 1        Maharashtra      626521.0
# 2          Rajasthan      571543.0
# 3     Andhra Pradesh      522093.0
# 4      Uttar Pradesh      435601.0
# 5          Karnataka      426341.0
# 6        West Bengal      315699.0
# 7            Gujarat      278137.0
# 8              Delhi      277463.0
# 9  Jammu and Kashmir      254059.0

# %%
"using pivot function to find cured , deaths , confirmed cases State wise"

statewise = pd.pivot_table(covid_india,values=['Cured','Deaths','Confirmed'],index='State/UnionTerritory',aggfunc='max',margins=True)
statewise
# Out:
#                                           Confirmed  Cured  Deaths
# State/UnionTerritory
# Andaman and Nicobar Islands                      38     33       0
# Andhra Pradesh                                 5680   3105      80
# Arunachal Pradesh                                67      4       0
# Assam                                          3498   1537       8
# Bihar                                          6103   3587      36
# Cases being reassigned to states               9227      0       0
# Chandigarh                                      334    286       5
# Chhattisgarh                                   1429    550       6
# Dadar Nagar Haveli                               26      2       0
# Dadra and Nagar Haveli and Daman and Diu         30      2       0
# Daman & Diu                                       2      0       0
# Delhi                                         36824  13398    1214
# Goa                                             463     69       0
# ...

# %%
"Top 10 states with most Active cases"

covid_top_10 = covid_india.nlargest(10,['Active'])

covid_top_10 = covid_india.groupby(['State/UnionTerritory'])['Active'].max().sort_values(ascending=False).reset_index()
covid_top = covid_top_10.nlargest(10,['Active'])
covid_top
# Out:
#                State/UnionTerritory  Active
# 0                       Maharashtra   49628
# 1                             Delhi   22212
# 2                        Tamil Nadu   18284
# 3  Cases being reassigned to states    9227
# 4                           Gujarat    6936
# 5                       West Bengal    5587
# 6                     Uttar Pradesh    4642
# 7                           Haryana    3789
# 8                         Karnataka    3259
# 9                         Rajasthan    3195

# %%
"Top 10 states with most deaths cases"

covid_deaths_top_10 = covid_india.nlargest(10,['Deaths'])

covid_deaths_top_10 = covid_india.groupby(['State/UnionTerritory'])['Deaths'].max().sort_values(ascending=False).reset_index()
covid_deaths = covid_deaths_top_10.nlargest(10,['Deaths'])

covid_deaths
# Out:
#   State/UnionTerritory  Deaths
# 0          Maharashtra    3717
# 1              Gujarat    1415
# 2                Delhi    1214
# 3          West Bengal     451
# 4       Madhya Pradesh     440
# 5           Tamil Nadu     367
# 6        Uttar Pradesh     365
# 7            Rajasthan     272
# 8            Telangana     174
# 9            Telengana     156

# %%
"Correlation amongs the columns"

statewise.corr()
# Out:
#            Confirmed     Cured    Deaths
# Confirmed   1.000000  0.990864  0.967591
# Cured       0.990864  1.000000  0.962450
# Deaths      0.967591  0.962450  1.000000

# %%
covid_state.corr()
# Out:
#               TotalSamples  Negative  Positive
# TotalSamples      1.000000  0.998360  0.709913
# Negative          0.998360  1.000000  0.668436
# Positive          0.709913  0.668436  1.000000

# %% [markdown]
# # Plotting the observations

# %%
"""Barplot for Confirmed , Deaths , Cured , Active"""
fig = plt.figure(figsize=(20,10))

Confirmed = covid_india['Confirmed'].sum()
Cured = covid_india['Cured'].sum()
Deaths = covid_india['Deaths'].sum()
Active = covid_india['Active'].sum()

print('Total Confirmed cases =',Confirmed)
print('Total Cured cases =',Cured)
print('Total Active cases =',Active)
print('Total Death cases =',Deaths)

barplot = sns.barplot(x=['Confirmed','Cured','Deaths','active'],y=[Confirmed,Cured,Deaths,Active])
barplot.set_yticklabels(labels=(barplot.get_yticks()*1).astype(int))

plt.show()
# Out:
# Total Confirmed cases = 6587180
# Total Cured cases = 2775246
# Total Active cases = 3617997
# Total Death cases = 193937

# %%
"Piechart for 'Confirmed','Cured',Deaths & 'Active'"

fig = plt.figure(figsize=(15,10))
covid_values = [covid_india['Confirmed'].sum(),covid_india['Cured'].sum(),covid_india['Deaths'].sum(),covid_india['Active'].sum()]
covid_keys = [Confirmed,Cured,Deaths,Active]


plt.pie(covid_keys,labels = covid_keys, explode = (0.02,0.02,0.1,0.02), autopct = '%.0f%%')
plt.legend(['Confirmed','Cured','Deaths','Active'])

# %%
"Pie Chart Of 10 Top states with Active Cases"

fig = plt.figure(figsize=(13,10))
covid_top.groupby(["State/UnionTerritory"]).sum()["Active"].plot(kind='pie',rot=90,explode=(0.05,0.02,0.03,0.04,0.04,0.05,0.1,0.04,0.09,0.04),autopct='%1.0f%%')
plt.title('Top 10 states with most Active cases',size=20)
plt.show()

# %%
"Bar Plot Of Top 10 Active Cases"

fig = plt.figure(figsize=(20,10))
sns.barplot(data = covid_top.iloc[:10],y='Active',x='State/UnionTerritory')
plt.title('Top 10 states with Most Active cases', size=20)
plt.show()

# %%
" Top 5 Most affected states"

fig = plt.figure(figsize=(15,10))
plot = sns.lineplot(data = covid_india[covid_india['State/UnionTerritory'].isin(['Maharashtra','Karnataka','Tamil Nadu','Delhi','Uttar Pradesh'])],x='Date',y='Active',hue = 'State/UnionTerritory',size='State/UnionTerritory')
plt.title('5 most affected states',size=20)
plt.show()

# %%
"Correlation Heatmap"

fig = plt.figure(figsize=(15,10))
sns.heatmap(covid_india.corr(),cmap="Reds",annot=True)
plt.title('Correlation Heatmap',size=20)
plt.show()

# %%
"Correlation Heatmap"

fig = plt.figure(figsize=(15,10))
sns.heatmap(covid_state.corr(),cmap="Reds",annot=True)
plt.title('Correlation Heatmap',size=20)
plt.show()

# %%
"Fatality ratio of contaminated states"

covid_india['Fatality_ratio']= covid_india['Deaths']/covid_india['Confirmed']
fig,ax = plt.subplots(figsize=(15,7))
sns.pointplot(data = covid_india,x='State/UnionTerritory',y='Fatality_ratio',ax=ax,color='Red')
plt.xticks(rotation=90)
plt.title('Fatality ratio of contaminated states',size=20)
plt.show()

# %%
state_top
# Out:
#                State  TotalSamples
# 0         Tamil Nadu      673906.0
# 1        Maharashtra      626521.0
# 2          Rajasthan      571543.0
# 3     Andhra Pradesh      522093.0
# 4      Uttar Pradesh      435601.0
# 5          Karnataka      426341.0
# 6        West Bengal      315699.0
# 7            Gujarat      278137.0
# 8              Delhi      277463.0
# 9  Jammu and Kashmir      254059.0

# %%
#Making a Datafram of top 5 sample testing states to further plot it
df_TamilNadu = covid_state[covid_state.State=='Tamil Nadu']
df_Mah = covid_state[covid_state.State=='Maharashtra']
df_Raj = covid_state[covid_state.State=='Rajasthan']
df_And = covid_state[covid_state.State=='Andhra Pradesh']
df_Utt = covid_state[covid_state.State=='Uttar Pradesh']

# %%
plt.figure(figsize=(10,6))

plt.title("Tamil Nadu") 
sns.lineplot(data=df_TamilNadu)
# Out:
# <AxesSubplot: title={'center': 'Tamil Nadu'}>

# %%
plt.figure(figsize=(10,6))
plt.title("Maharashtra") 
sns.lineplot(data=df_Mah)
# Out:
# <AxesSubplot: title={'center': 'Maharashtra'}>

# %%
covid_state
# Out:
#             Date                        State  TotalSamples  Negative  \
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0    1391.0
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0    2652.0
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0    2815.0
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0    3721.0
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0    6644.0
# ...          ...                          ...           ...       ...
# 1989  2020-06-08                  West Bengal      280098.0  271485.0
# 1990  2020-06-09                  West Bengal      287900.0  278915.0
# 1991  2020-06-10                  West Bengal      297419.0  288091.0
# 1992  2020-06-11                  West Bengal      306941.0  297173.0
# 1993  2020-06-12                  West Bengal      315699.0  305455.0
#
#       Positive
# 0         12.0
# 1         27.0
# 2         33.0
# 3         33.0
# 4         33.0
# ...        ...
# ...

# %%
plt.figure(figsize=(10,6))
plt.title("Rajasthan") 
sns.lineplot(data=df_Raj)
# Out:
# <AxesSubplot: title={'center': 'Rajasthan'}>

# %%
plt.figure(figsize=(10,6))
plt.title("Andhra Pradesh") 
sns.lineplot(data=df_And)
# Out:
# <AxesSubplot: title={'center': 'Andhra Pradesh'}>

# %%
plt.figure(figsize=(10,6))
plt.title("Uttar Pradesh") 
sns.lineplot(data=df_Utt)
# Out:
# <AxesSubplot: title={'center': 'Uttar Pradesh'}>

# %%
sns.lineplot(x="TotalPositiveCases", y="Recovered", data=italy_region)
plt.title('Italy')
# Out:
# Text(0.5, 1.0, 'Italy')

# %%
sns.lineplot(x="TotalPositiveCases", y="Deaths", data=italy_region)
plt.title('Italy')
# Out:
# Text(0.5, 1.0, 'Italy')

# %%
sns.relplot(x="TotalPositiveCases", y="CurrentPositiveCases", data=italy_region)
plt.title('Italy')
# Out:
# Text(0.5, 1.0, 'Italy')

# %%
sns.relplot(x="TotalPositiveCases", y="HospitalizedPatients", data=italy_region)
plt.title('Italy')
# Out:
# Text(0.5, 1.0, 'Italy')

# %%
sns.relplot(x="TotalPositiveCases", y="HospitalizedPatients", hue="Recovered", data=italy_region)
plt.title('Italy')
# Out:
# Text(0.5, 1.0, 'Italy')
